# %%
# Constants for the Sun and Jupiter
R_sun = 696340 * u.km  # Radius of the Sun
R_jupiter = 69911 * u.km  # Radius of Jupiter

# Calculating the fraction of the Sun covered by Jupiter
fraction_covered = (R_jupiter / R_sun)**2

print(f"Fraction of the Sun covered by Jupiter as seen by the space probe: {fraction_covered:.4e}")
# Out:
# Fraction of the Sun covered by Jupiter as seen by the space probe: 1.0080e-02
