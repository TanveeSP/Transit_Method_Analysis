# %%
# flux of the Sun (F_initial) at Earth
F_sun = 1370 * u.W / u.m**2

# Calculating the flux after the transit (F_final)
F_final = F_sun * (1 - fraction_covered)

# Calculating the change in magnitude
delta_m = -2.5 * np.log10(F_final / F_sun)

print(f"Change in magnitude due to the transit of Jupiter: {delta_m:.4f}")
# Out:
# Change in magnitude due to the transit of Jupiter: 0.0110
